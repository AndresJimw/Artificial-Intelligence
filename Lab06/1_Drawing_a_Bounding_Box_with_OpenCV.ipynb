# %% [markdown]
# # **Tutorial:** Drawing a Bounding Box with OpenCV

# %% [markdown]
# In this tutorial, you will learn how to use the OpenCV library in Python to load an image and draw a bounding box around an object. This is a fundamental step before moving on to object detection with YOLO.

# %% [markdown]
# ### **Step 1: Install OpenCV**
#
# If you don't have OpenCV installed, you can install it using pip:

# %%
# %pip install --upgrade opencv-python
# %pip install --upgrade matplotlib

# %% [markdown]
# Verify the installed version number:

# %%
# %pip show opencv-python
# Out:
# Name: opencv-python
# Version: 4.9.0.80
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: d:\archivos de usuario\documents\artificial-intelligence\ai_env\lib\site-packages
# Requires: numpy
# Required-by: retina-face
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **Step 2: Import Required Libraries**
#
# Import the libraries you will use:

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the Image**
#
# Use OpenCV's `imread` function to load your image.
#
# Replace the path with the location of your image file.

# %%
# Load the image (change the path to your image file)
image_bgr = cv2.imread(r'D:\Archivos de Usuario\Documents\Artificial-Intelligence\Lab06\images\cat.jpg')

# %%
# Print the shape of the image (height, width, channels)
print('Image shape:', image_bgr.shape)
# Out:
# Image shape: (183, 275, 3)

# %% [markdown]
# ### **Step 4: Show the image**

# %%
# Convert BGR to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# ### **Step 5: Draw the Bounding Box**
#
# To draw a bounding box, use OpenCV's `rectangle` function.
#
# You need to specify the coordinates of the **top-left** point $(x1, y1)$ and the **bottom-right** point $(x2, y2)$ of the bounding box.
#
# The coordinates should be within the image dimensions

# %%
x1, y1 = 90, 0  # Top-left corner
x2, y2 = 230, 160  # Bottom-right corner

# Draw the bounding box on the input image using cv2.rectangle
# Arguments: image, (x1, y1), (x2, y2), bounding box color in BGR, thickness
image_bgr_box = cv2.rectangle(image_bgr, (x1, y1), (x2, y2), (0, 255, 0), 15)  # Green box, thickness 15

# %% [markdown]
# ### **Step 6: Display the Image**
#
# Finally, use matplotlib to display the image with the bounding box.

# %%
# Convert the image from BGR (OpenCV format) to RGB (matplotlib format)
image_rgb_box = cv2.cvtColor(image_bgr_box, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb_box)
plt.show()

# %% [markdown]
# You should now see your image with a bounding box drawn around the object.
#
# You can adjust the bounding box coordinates as needed to fit the object you want to highlight.

# %% [markdown]
# ### **Activity:**

# %% [markdown]
# 1. Load an image containing **at least two different objects** using `cv2.imread`.

# %%
activity_img_bgr = cv2.imread(r'D:\Archivos de Usuario\Documents\Artificial-Intelligence\Lab06\images\pizza_burger.jpg')

print('Activity image shape:', activity_img_bgr.shape)

activity_img_rgb = cv2.cvtColor(activity_img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(activity_img_rgb)
plt.show()
# Out:
# Activity image shape: (159, 318, 3)

# %% [markdown]
# 2. Draw **different colored bounding boxes** around each object. Use a **line thickness** of 5 for both bounding boxes.

# %%
# Object 1: Pizza
x1a, y1a = 10, 10      # Top-left corner
x2a, y2a = 160, 154    # Bottom-right corner

# Object 2: Burger
x1b, y1b = 165, 30     # Top-left corner
x2b, y2b = 290, 140    # Bottom-right corner

# Draw boxes with thickness 5 and different colors
img_boxes_bgr = activity_img_bgr.copy()
img_boxes_bgr = cv2.rectangle(img_boxes_bgr, (x1a, y1a), (x2a, y2a), (0, 255, 0), 5)   # green box (pizza)
img_boxes_bgr = cv2.rectangle(img_boxes_bgr, (x1b, y1b), (x2b, y2b), (255, 0, 0), 5)   # blue box (burger)

# %% [markdown]
# 3. Add **text labels** above each bounding box (e.g., “Cat”, “Ball”, etc.) using `cv2.putText`.

# %%
cv2.putText(img_boxes_bgr, "Pizza",  (x1a + 5, y1a + 20),
            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2, cv2.LINE_AA)

cv2.putText(img_boxes_bgr, "Burger", (x1b + 5, y1b + 20),
            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2, cv2.LINE_AA)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# 4. Display the **resulting image**.

# %%
img_boxes_rgb = cv2.cvtColor(img_boxes_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_boxes_rgb)
plt.show()

# %% [markdown]
# 5. Suggest one way to **automatically detect objects** instead of manual coordinates.

# %% [markdown]
# A good way to do this would be to use a model such as YOLO, which is already trained to detect objects automatically. This model analyzes the entire image and, instead of requiring us to manually define the coordinates, it identifies the objects, determines their locations, and draws the bounding boxes on its own. For example, if we use the picture with the pizza and the burger, the model detects both and marks them with its own boxes. It works as a visual detector capable of recognizing multiple types of objects at once, saving us from doing the process manually.

# %% [markdown]
# ### **Grading Rubric:**

# %% [markdown]
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Image Loading** | 1 | Successfully loads an image with at least two objects using `cv2.imread`. Correct file path and proper handling of image object. |
# | **2. Bounding Boxes** | 3 | Draws **different colored bounding boxes** around each object. Boxes have correct size and position, and line thickness is set to 5. |
# | **3. Text Labels** | 2 | Adds **accurate text labels** above each bounding box using `cv2.putText`. Labels are readable and positioned correctly. |
# | **4. Automatic Detection Suggestion** | 4 | Provides a clear and reasonable method to detect objects automatically. Shows understanding of dynamic object detection. |
#
# Total: 10 points

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
